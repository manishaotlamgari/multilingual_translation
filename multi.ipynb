# %% [markdown]
# <a href="https://colab.research.google.com/github/manishaotlamgari/multilingual_translation/blob/main/multi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f16ac8b5-a4ec-4aa3-937d-e6cbe2691e45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f16ac8b5-a4ec-4aa3-937d-e6cbe2691e45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# %cd /content/drive/MyDrive/multi/Multilingual-Voice-Transcriber-and-Translator-main
# Out:
# /content/drive/MyDrive/multi/Multilingual-Voice-Transcriber-and-Translator-main

# %%
# !apt-get install -y portaudio19-dev
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# portaudio19-dev is already the newest version (19.6.0-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.

# %%
# !pip install pyaudio

# %%
import pyaudio
print(pyaudio.__version__)
# Out:
# 0.2.14

# %%
pip install -r requirements.txt

# %%
# !pip install SpeechRecognition googletrans==4.0.0-rc1 gtts pydub ipywidgets
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.2 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17397 sha256=149d7eba191ebc26fdf9f70b6327c4f21001ef5cd7092f4d23fca316ce21ccfb
#   Stored in directory: /root/.cache/pip/wheels/39/17/6f/66a045ea3d168826074691b4b787b8f324d3f646d755443fda
# Successfully built googletrans
# ...

# %%
# !apt-get update
# !apt-get install -y libpulse-dev
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,370 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,668 kB]
# ...

# %%
# !pip install pyqt5

# %%
# !pip install SpeechRecognition googletrans==4.0.0-rc1 gtts pydub ipywidgets

# %%
# !apt-get update
# !apt-get install -y libx11-dev libxcb-xinerama0-dev
# !apt-get install -y libglu1-mesa libxrender1 libxi6 libgdk-pixbuf2.0-0
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
# !pip install SpeechRecognition googletrans==4.0.0-rc1 gtts pydub ipywidgets

# %%
# !pip install noisereduce

# %%
import os
import json
import speech_recognition as sr
import noisereduce as nr
import numpy as np
import wave
from googletrans import Translator  # Use Google Translate API
from gtts import gTTS
import IPython.display as ipd
import ipywidgets as widgets
from IPython.display import display
from google.colab import files
from pydub import AudioSegment

# Load language codes from JSON file
with open('language_codes.json', 'r') as f:
    language_dict = json.load(f)  # Dictionary: {"English": "en", "French": "fr", ...}

# UI Elements
upload_button = widgets.FileUpload(accept=".wav,.mp3", multiple=False)
language_dropdown = widgets.SelectMultiple(
    options=language_dict.keys(), description="Languages:", layout={'width': 'max-content'}
)
status_label = widgets.Label(value="Status: Ready")
spoken_text_area = widgets.Textarea(description="Spoken Text", layout={'width': '100%', 'height': '100px'})
translated_text_areas = {}  # Dictionary to hold text areas for each language
download_buttons = {}  # Dictionary to hold download buttons

# Function to reduce noise
def reduce_noise(file_name):
    with wave.open(file_name, "rb") as wf:
        params = wf.getparams()
        audio_data = wf.readframes(wf.getnframes())
        audio_array = np.frombuffer(audio_data, dtype=np.int16)
        reduced_noise = nr.reduce_noise(y=audio_array, sr=params.framerate)

    # Save cleaned audio
    cleaned_file = "cleaned_audio.wav"
    with wave.open(cleaned_file, "wb") as wf:
        wf.setparams(params)
        wf.writeframes(reduced_noise.astype(np.int16).tobytes())

    return cleaned_file

# Function to process uploaded audio
def process_audio(change):
    status_label.value = "Status: Processing file..."

    # Get uploaded file
    uploaded_file = next(iter(upload_button.value))
    file_name = uploaded_file
    with open(file_name, 'wb') as f:
        f.write(upload_button.value[file_name]['content'])

    # Convert MP3 to WAV if necessary
    if file_name.endswith('.mp3'):
        audio = AudioSegment.from_mp3(file_name)
        file_name = "converted_audio.wav"
        audio.export(file_name, format="wav")

    # Reduce noise
    file_name = reduce_noise(file_name)

    # Speech recognition
    recognizer = sr.Recognizer()
    with sr.AudioFile(file_name) as source:
        audio_data = recognizer.record(source)

    try:
        spoken_text = recognizer.recognize_google(audio_data)
        spoken_text_area.value = spoken_text
        status_label.value = "Status: Recognized Speech"

        # Translate text into selected languages
        translator = Translator()
        selected_languages = language_dropdown.value

        # Remove old text areas and buttons
        for lang in translated_text_areas:
            translated_text_areas[lang].close()
            download_buttons[lang].close()

        translated_text_areas.clear()
        download_buttons.clear()

        for lang in selected_languages:
            lang_code = language_dict[lang]
            translated_text = translator.translate(spoken_text, dest=lang_code).text

            # Create a text area for translated text
            translated_text_area = widgets.Textarea(
                value=translated_text, description=f"{lang}:", layout={'width': '100%', 'height': '100px'}
            )
            translated_text_areas[lang] = translated_text_area
            display(translated_text_area)

            # Convert translated text to speech and save
            tts = gTTS(translated_text, lang=lang_code)
            audio_filename = f"translated_audio_{lang_code}.mp3"
            tts.save(audio_filename)

            # Create a download button for the audio file
            def download_audio(file_name):
                def func(b):
                    files.download(file_name)
                return func

            download_button = widgets.Button(description=f"Download {lang} Audio", button_style="primary")
            download_button.on_click(download_audio(audio_filename))
            download_buttons[lang] = download_button
            display(download_button)

        status_label.value = "Status: Translation & Audio Ready"

    except Exception as e:
        status_label.value = f"Error: {e}"

# Bind upload button
upload_button.observe(process_audio, names='value')

# Display UI
display(upload_button, language_dropdown, status_label, spoken_text_area)
# Out:
# FileUpload(value={}, accept='.wav,.mp3', description='Upload')
# SelectMultiple(description='Languages:', layout=Layout(width='max-content'), options=('Translate to ...', 'Afr…
# Label(value='Status: Ready')
# Textarea(value='', description='Spoken Text', layout=Layout(height='100px', width='100%'))
# Textarea(value='ما اسمك', description='Arabic:', layout=Layout(height='100px', width='100%'))
# Button(button_style='primary', description='Download Arabic Audio', style=ButtonStyle())
# Textarea(value='Как се казваш', description='Bulgarian:', layout=Layout(height='100px', width='100%'))
# Button(button_style='primary', description='Download Bulgarian Audio', style=ButtonStyle())
# Textarea(value='আপনার নাম কি', description='Bengali:', layout=Layout(height='100px', width='100%'))
# Button(button_style='primary', description='Download Bengali Audio', style=ButtonStyle())
